# %%
import pandas as pd

# %%
race_by_tract = pd.read_csv('../data/davidson_race_by_tract/davidson_race_by_tract.csv')

# %%
race_by_tract.head()
# Out:
#                 geoid                               name  B02001001  \
# 0             01000US                      United States  324697795
# 1           04000US47                          Tennessee    6709356
# 2        05000US47037                Davidson County, TN     687488
# 3  14000US47037010103  Census Tract 101.03, Davidson, TN       2533
# 4  14000US47037010104  Census Tract 101.04, Davidson, TN       2955
#
#    B02001001, Error  B02001002  B02001002, Error  B02001003  B02001003, Error  \
# 0                 0  235377662             54551   41234642             32548
# 1                 0    5205132              4583    1124473              3575
# 2                 0     440299              1694     186295              1403
# 3               191       2457               201          7                10
# 4               279       2713               268        167               136
#
#    B02001004  B02001004, Error  ...  B02001006  B02001006, Error  B02001007  \
# ...
