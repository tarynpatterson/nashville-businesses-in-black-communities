# %%
import pandas as pd
import geopandas as gpd

# %%
race_geo = gpd.read_file('../data/davidson_race_by_tract/davidson_race_by_tract.geojson')

# %%
race_geo.head()
# Out:
#                 geoid                               name    B02001001  \
# 0             01000US                      United States  324697795.0
# 1           04000US47                          Tennessee    6709356.0
# 2        05000US47037                Davidson County, TN     687488.0
# 3  14000US47037010103  Census Tract 101.03, Davidson, TN       2533.0
# 4  14000US47037010104  Census Tract 101.04, Davidson, TN       2955.0
#
#    B02001001, Error    B02001002  B02001002, Error   B02001003  \
# 0               0.0  235377662.0           54551.0  41234642.0
# 1               0.0    5205132.0            4583.0   1124473.0
# 2               0.0     440299.0            1694.0    186295.0
# 3             191.0       2457.0             201.0         7.0
# 4             279.0       2713.0             268.0       167.0
#
#    B02001003, Error  B02001004  B02001004, Error  ...  B02001006, Error  \
# 0           32548.0  2750143.0           13011.0  ...            4711.0
# ...

# %%
davidson_w_b = race_geo[['geoid', 'name', 'B02001001', 'B02001001, Error', 'B02001002', 'B02001002, Error', 'B02001003', 'B02001003, Error', 'geometry']]

# %%
davidson_w_b.head()
# Out:
#                 geoid                               name    B02001001  \
# 0             01000US                      United States  324697795.0
# 1           04000US47                          Tennessee    6709356.0
# 2        05000US47037                Davidson County, TN     687488.0
# 3  14000US47037010103  Census Tract 101.03, Davidson, TN       2533.0
# 4  14000US47037010104  Census Tract 101.04, Davidson, TN       2955.0
#
#    B02001001, Error    B02001002  B02001002, Error   B02001003  \
# 0               0.0  235377662.0           54551.0  41234642.0
# 1               0.0    5205132.0            4583.0   1124473.0
# 2               0.0     440299.0            1694.0    186295.0
# 3             191.0       2457.0             201.0         7.0
# 4             279.0       2713.0             268.0       167.0
#
#    B02001003, Error                                           geometry
# 0           32548.0  MULTIPOLYGON (((-168.22527 -14.53591, -168.199...
# ...

# %%
davidson_w_b.rename(columns={'B02001001': 'total_pop', 'B02001001, Error': 'total_pop_MOE', 'B02001002': 'white_alone', 'B02001002, Error': 'white_alone_MOE', 'B02001003': 'black_africanamerican_alone', 'B02001003, Error': 'black_africanamerican_alone_MOE'}, inplace=True)
# Out:
# C:\Users\16159\anaconda3\envs\geospatial\lib\site-packages\pandas\core\frame.py:5039: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   return super().rename(

# %%
davidson_w_b
# Out:
#                   geoid                               name    total_pop  \
# 0               01000US                      United States  324697795.0
# 1             04000US47                          Tennessee    6709356.0
# 2          05000US47037                Davidson County, TN     687488.0
# 3    14000US47037010103  Census Tract 101.03, Davidson, TN       2533.0
# 4    14000US47037010104  Census Tract 101.04, Davidson, TN       2955.0
# ..                  ...                                ...          ...
# 159  14000US47037019400     Census Tract 194, Davidson, TN       5810.0
# 160  14000US47037019500     Census Tract 195, Davidson, TN       7956.0
# 161  14000US47037019600     Census Tract 196, Davidson, TN       3843.0
# 162  14000US47037980100    Census Tract 9801, Davidson, TN          0.0
# 163  14000US47037980200    Census Tract 9802, Davidson, TN          0.0
#
#      total_pop_MOE  white_alone  white_alone_MOE  black_africanamerican_alone  \
# ...

# %%
davidson_w_b.to_file('../data/davidson_race_by_tract/davidson_race_by_tract_clean.geojson')
